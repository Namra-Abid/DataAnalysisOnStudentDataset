# %%
import pandas as pd
student_df= pd.read_csv('student.csv')
student_df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
stntKuwait=student_df[student_df['PlaceofBirth']=='KuwaIT']
#stntKuwait
IT_topic=student_df[student_df['Topic']=='IT']
(IT_topic)
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 1        M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 2        M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 3        M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 4        M          KW       KuwaIT    lowerlevel    G-04         A    IT
# ..     ...         ...          ...           ...     ...       ...   ...
# 132      M          KW       KuwaIT    lowerlevel    G-02         C    IT
# 133      M          KW       KuwaIT    lowerlevel    G-02         A    IT
# 244      M          KW       KuwaIT  MiddleSchool    G-07         B    IT
# 245      F          KW       KuwaIT  MiddleSchool    G-06         A    IT
# 249      M          KW       KuwaIT    lowerlevel    G-04         A    IT
#
#     Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# ...

# %%
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
countries_of_student=student_df.PlaceofBirth.unique()
countries_of_student
#sns.scatterplot(x=student_df.raisedhands, y=student_df.Discussion, hue=, s=100);
# Out:
# array(['KuwaIT', 'lebanon', 'Egypt', 'SaudiArabia', 'USA', 'Jordan',
#        'venzuela', 'Iran', 'Tunis', 'Morocco', 'Syria', 'Iraq',
#        'Palestine', 'Lybia'], dtype=object)

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=IT_topic.raisedhands, y=IT_topic.Discussion, hue=IT_topic.gender, s=150);

# %%
#kuwait student interest discussion wise and raised hand wise in  chemistry
topicHistory=stntKuwait[stntKuwait['Topic']=='Chemistry']
plt.figure(figsize=(12, 6))
sns.scatterplot(x=stntKuwait.raisedhands, y=stntKuwait.Discussion, hue=topicHistory.gender, s=100);

# %%
#kuwait student interest discussion wise and raised hand wise in  Geology
topicGeology=stntKuwait[stntKuwait['Topic']=='Geology']
plt.figure(figsize=(12, 6))
sns.scatterplot(x=stntKuwait.raisedhands, y=stntKuwait.Discussion, hue=topicGeology.gender, s=100);

# %%
#kuwait student interest discussion wise and raised hand wise in  History
topicHistory=stntKuwait[stntKuwait['Topic']=='History']
plt.figure(figsize=(12, 6))
sns.scatterplot(x=stntKuwait.raisedhands, y=stntKuwait.Discussion, hue=topicHistory.gender, s=100);

# %%
Topics =student_df.Topic.unique()
Topics
# Out:
# array(['IT', 'Math', 'Arabic', 'Science', 'English', 'Quran', 'Spanish',
#        'French', 'History', 'Biology', 'Chemistry', 'Geology'],
#       dtype=object)

# %%
topicQuran=student_df[student_df.Topic=='Quran']
topicQuran
# Out:
#     gender  NationalITy PlaceofBirth       StageID GradeID SectionID  Topic  \
# 45       M           KW       KuwaIT  MiddleSchool    G-07         A  Quran
# 75       M       Jordan       Jordan  MiddleSchool    G-07         A  Quran
# 78       M           KW       KuwaIT    HighSchool    G-11         A  Quran
# 134      M           KW       KuwaIT  MiddleSchool    G-07         A  Quran
# 135      F        Egypt        Egypt  MiddleSchool    G-07         A  Quran
# 136      F           KW          USA    HighSchool    G-11         A  Quran
# 137      F           KW          USA    HighSchool    G-11         A  Quran
# 138      F       Jordan        Egypt  MiddleSchool    G-07         A  Quran
# 139      M       Jordan          USA  MiddleSchool    G-07         A  Quran
# 140      M        Tunis        Tunis  MiddleSchool    G-07         A  Quran
# 141      M        Tunis        Tunis  MiddleSchool    G-07         A  Quran
# ...

# %%
#overallworld student discussion and raised hand in quran
plt.figure(figsize=(12, 6))
sns.scatterplot(x=student_df.raisedhands, y=student_df.Discussion, hue=topicQuran.gender, s=100);

# %%
topicMath=student_df[student_df.Topic=='Math']
topicMath
# Out:
#     gender  NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
# 6        M           KW       KuwaIT  MiddleSchool    G-07         A  Math
# 7        M           KW       KuwaIT  MiddleSchool    G-07         A  Math
# 8        F           KW       KuwaIT  MiddleSchool    G-07         A  Math
# 10       M           KW       KuwaIT  MiddleSchool    G-07         A  Math
# 11       M           KW       KuwaIT  MiddleSchool    G-07         B  Math
# 13       M      lebanon      lebanon  MiddleSchool    G-08         A  Math
# 14       F           KW       KuwaIT  MiddleSchool    G-08         A  Math
# 17       M           KW       KuwaIT  MiddleSchool    G-07         A  Math
# 55       M           KW       KuwaIT  MiddleSchool    G-07         A  Math
# 56       M          USA          USA  MiddleSchool    G-08         B  Math
# 57       M           KW       KuwaIT  MiddleSchool    G-07         A  Math
# ...

# %%
#overallworld student discussion and raised hand in Math
plt.figure(figsize=(12, 6))
sns.scatterplot(x=student_df.raisedhands, y=student_df.Discussion, hue=topicMath.gender, s=50);
